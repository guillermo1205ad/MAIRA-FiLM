# %%
import os

# Descargar y descomprimir el dataset CLEVR si no existe
if not os.path.exists('/home/gperaltag/mi_entorno/'):
    print("Descargando el dataset CLEVR...")
    # Descargar el archivo .zip en la carpeta /content/
    # !wget -nc https://dl.fbaipublicfiles.com/clevr/CLEVR_v1.0.zip -P /home/gperaltag/mi_entorno/

    print("Descomprimiendo el dataset...")
    # Descomprimir el archivo .zip en /content/
    # !unzip -qn /home/gperaltag/mi_entorno/CLEVR_v1.0.zip -d /home/gperaltag/mi_entorno/

    print("Eliminando el archivo ZIP...")
    # Eliminar el archivo ZIP para liberar espacio
    os.remove('/home/gperaltag/mi_entorno/CLEVR_v1.0.zip')
else:
    print("El dataset CLEVR ya está disponible en /home/gperaltag/mi_entorno/CLEVR_v1.0.")


# !wget -O CLEVR_sample_10_000.tar.gz "https://www.dropbox.com/scl/fi/l87paducv9fmmkiymjfaw/CLEVR_sample_10_000.tar.gz?rlkey=pulv7wktvocicadq6miv3rbbz&st=lmq0fikc&dl=1"

# !mkdir -p data
# !tar -xzvf CLEVR_sample_10_000.tar.gz -C data/
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064565.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_065742.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_066629.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_066637.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_066682.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067882.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069109.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069431.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025447.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039514.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047316.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_019502.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050922.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_038794.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047562.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035744.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_046620.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052107.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058284.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_012662.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052142.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_022671.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_041541.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_028845.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058713.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_033862.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_040825.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_059694.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_007938.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039496.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_059346.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_046259.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031279.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031716.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025085.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_020169.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_055542.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_005745.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047730.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_000716.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025618.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_037293.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_037287.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_012437.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_041303.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058559.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_017277.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_004346.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_026393.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_048346.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036430.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_059266.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_005698.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058542.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_008305.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_027726.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058700.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_012322.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031160.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_040721.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_028588.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006514.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_054135.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052153.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044151.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044349.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_016431.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_015331.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056590.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_038242.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_011627.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_002386.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_060429.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_061005.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_061049.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_062505.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064204.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_065010.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_066362.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067396.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067406.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067600.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_068049.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_068433.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_003378.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_022945.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025361.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_012807.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_041656.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_055025.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_049766.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_055350.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_054359.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_026756.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_037300.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_024741.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006330.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_030887.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050865.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006588.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_017362.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044306.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_060561.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058146.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_037687.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053768.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_000971.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053980.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056237.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_054255.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051995.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_032302.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031993.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_040909.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047546.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_013623.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_049235.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053028.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_054583.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025721.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050933.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_017201.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057734.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_009241.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050886.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035032.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_018405.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_059414.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_046474.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051923.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_034182.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_024419.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_013933.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025460.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052091.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047112.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031636.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036625.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053088.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_000429.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_023866.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_034934.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_028896.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_016027.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_007728.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039221.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_005436.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_033338.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_060877.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_060901.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_062630.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064564.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_065429.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067002.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067016.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_068953.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069607.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069636.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_045648.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_018989.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_012008.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044006.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_029690.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006998.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051971.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_045868.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_005967.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_013496.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_060966.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039660.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_007827.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006946.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_055312.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056822.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057653.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_028664.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058301.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_037433.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_060509.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_005633.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_000314.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058785.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047820.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051245.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044420.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_005639.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_042011.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_022834.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_019447.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_010321.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053372.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050819.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_026366.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050551.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_014754.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031854.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_008418.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_059271.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031663.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_028027.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_041582.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_041142.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057326.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047040.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_023262.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_040752.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006529.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_020349.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_020956.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_032537.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_046855.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_020221.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056628.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_021162.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051893.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052008.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_001430.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_026819.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_021211.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_001087.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036310.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_018026.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_062128.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_063854.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_063873.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_066681.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_066817.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067768.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067774.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_068803.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069171.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069353.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_010030.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_030984.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_045948.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_034693.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_033986.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036219.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_014324.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_032959.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_037580.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_002260.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044218.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_046515.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_002903.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_016829.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_026358.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_024341.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_029530.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_019286.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058539.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051027.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_023094.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036105.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_029878.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_003596.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_007174.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025370.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_004627.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_002394.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056224.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_019949.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_027843.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_032011.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039469.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025179.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047981.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_043489.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_008097.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_024961.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_016282.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_033133.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035401.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_011209.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_022959.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_009584.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_049441.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052957.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052516.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_021047.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_055256.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057287.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_004474.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047842.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_002985.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_026236.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_011026.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047855.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058693.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_020775.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057633.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051651.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_019457.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_017032.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047013.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_023000.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_062207.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_062268.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064273.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064677.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_065249.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067335.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067633.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_068166.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_068267.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069858.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069983.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_063221.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_047440.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_019396.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_017949.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057253.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050389.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056285.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_055186.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035619.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_046843.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_013680.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_004549.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_037011.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_012708.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_009876.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_005809.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031862.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_026526.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_011178.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036968.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_045629.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036069.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_059648.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_048389.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_062771.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_022685.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_001489.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036258.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_027011.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_001947.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_013038.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_063059.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025121.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_024696.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_042168.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_048009.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_043911.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035648.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_061166.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006937.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_021992.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_017737.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_029077.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_030516.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025278.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_040978.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053203.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_049254.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039497.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_003569.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051074.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057983.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_055288.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053790.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_007858.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031170.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035672.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052168.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_003238.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_048037.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_022922.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_002769.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_046534.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_036027.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_063274.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_065038.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_065515.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_066714.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067703.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_067752.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_004967.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052356.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_013196.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_062844.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056441.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_043774.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_025433.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_024511.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_010544.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_015140.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_032600.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_052753.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_042350.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_057984.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_038643.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_000622.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_028134.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051210.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_014963.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_045370.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_054471.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035878.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_004179.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_043477.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_051608.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044889.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006144.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_009425.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_020931.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_016032.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039817.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_050579.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_061608.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_010407.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_049299.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_061299.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_044561.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_016713.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_060431.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_028628.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_023029.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_053663.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_011613.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_041085.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_023666.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_022192.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_031858.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_027895.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_063266.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_039270.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058392.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_056035.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_041562.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_058500.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_018439.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_011430.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_034753.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_001175.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_061374.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_008096.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_035315.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_045246.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_030743.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_012739.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064354.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064466.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064846.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_064984.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_065808.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_069252.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/trainA/CLEVR_trainA_006454.png
# ...
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000082.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013098.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014562.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008799.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006385.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006888.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004015.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004151.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008512.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010604.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011172.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008594.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001812.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008509.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011134.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002817.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010195.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012021.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002527.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006919.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011318.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000495.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012125.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001845.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014906.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008964.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011277.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010585.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006163.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000736.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012043.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006918.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012936.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009359.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008168.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012493.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013077.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012573.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013955.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009627.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004662.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012611.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010133.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007304.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_005297.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000879.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001894.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009174.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008324.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000820.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014011.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012678.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006138.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006143.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004896.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014745.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011496.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_005607.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007713.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009581.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007241.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000077.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011072.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004831.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009246.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011043.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012956.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012743.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008754.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_003785.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002112.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_005091.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012042.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000223.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001006.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008912.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_005710.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002383.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007964.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007050.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014605.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007978.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002446.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009794.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008233.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006447.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010373.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001574.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006253.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014757.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006294.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013475.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010668.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001865.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_003972.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000102.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013242.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013733.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009459.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_003619.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009685.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009085.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010882.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007408.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011786.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001500.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001082.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010574.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000248.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_008804.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014802.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012017.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013793.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011088.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_005159.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014751.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014501.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010245.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013160.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000005.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_011966.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000834.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010656.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012362.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002002.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014516.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_012374.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_005482.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013313.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001519.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_001562.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002315.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009936.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014283.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000019.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002724.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007927.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010338.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000904.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009901.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_005080.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004165.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014678.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_000014.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_002397.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_006423.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_013479.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_009318.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_010745.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_007250.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004564.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004024.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_004235.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014039.png
# mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2/images/valB/CLEVR_valB_014966.png

# %%
import os
import json
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset
from PIL import Image
from tqdm import tqdm
from sklearn.metrics import accuracy_score

# Deshabilitar cuDNN para evitar problemas con GRU
torch.backends.cudnn.enabled = False

# Definir las rutas exactas basadas en la estructura de archivos proporcionada
clevr_original_dir = '/home/gperaltag/mi_entorno/CLEVR_v1.0'
clevr_systematic_10k_dir = '/content/data/mnt/ialabnas/datasets/CLEVR_CoGenT_v1.0/CLEVR_sample_10_000/sample_2'

# ------------------- Función para Calcular max_length -------------------

def calculate_max_length(question_file):
    with open(question_file, 'r') as f:
        questions = json.load(f)['questions']
    return max(len(q['question']) for q in questions)

# ------------------- Definición del Modelo -------------------

class FiLMResBlock(nn.Module):
    def __init__(self, in_channels):
        super(FiLMResBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, in_channels, kernel_size=1)
        self.conv2 = nn.Conv2d(in_channels, in_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU()

    def forward(self, x, gamma, beta):
        out = self.conv1(x)
        out = self.conv2(self.relu(out))
        gamma = gamma.unsqueeze(2).unsqueeze(3)
        beta = beta.unsqueeze(2).unsqueeze(3)
        out = gamma * out + beta
        return self.relu(out)

class FiLMNetwork(nn.Module):
    def __init__(self, num_classes, max_length, use_resnet=True):
        super(FiLMNetwork, self).__init__()
        resnet = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
        for param in resnet.parameters():
            param.requires_grad = False
        self.feature_extractor = nn.Sequential(
            resnet.conv1,
            resnet.bn1,
            resnet.relu,
            resnet.maxpool,
            resnet.layer1,
            resnet.layer2,
            resnet.layer3
        )
        self.reduce_channels = nn.Conv2d(1024 + 2, 128, kernel_size=1)
        self.resblocks = nn.ModuleList([FiLMResBlock(128) for _ in range(4)])
        self.word_embedding = nn.Embedding(256, 200)
        self.gru = nn.GRU(input_size=200, hidden_size=4096, batch_first=True)
        self.affine_gamma = nn.Linear(4096, 128)
        self.affine_beta = nn.Linear(4096, 128)
        self.classifier = nn.Sequential(
            nn.Conv2d(128, 512, kernel_size=1),
            nn.ReLU(),
            nn.AdaptiveMaxPool2d(1),
            nn.Flatten(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, num_classes)
        )

    def add_coordinates(self, features):
        batch_size, _, height, width = features.size()
        x_coords = torch.linspace(-1, 1, steps=width).repeat(batch_size, height, 1).unsqueeze(1)
        y_coords = torch.linspace(-1, 1, steps=height).repeat(batch_size, width, 1).unsqueeze(1).transpose(2, 3)
        coords = torch.cat([x_coords, y_coords], dim=1).to(features.device)
        return torch.cat([features, coords], dim=1)

    def forward(self, images, questions):
        features = self.feature_extractor(images)
        features = self.add_coordinates(features)
        features = self.reduce_channels(features)
        question_embedding = self.gru_forward(questions)
        gamma = self.affine_gamma(question_embedding)
        beta = self.affine_beta(question_embedding)
        for resblock in self.resblocks:
            features = resblock(features, gamma, beta)
        return self.classifier(features)

    def gru_forward(self, questions):
        embedded = self.word_embedding(questions)
        _, hidden = self.gru(embedded)
        return hidden.squeeze(0)

# ------------------- Definición del Dataset -------------------

class CLEVRDataset(Dataset):
    def __init__(self, image_dir, question_file, max_length, transform=None):
        self.image_dir = image_dir
        with open(question_file, 'r') as f:
            self.questions = json.load(f)['questions']
        self.transform = transform
        self.max_length = max_length

    def __len__(self):
        return len(self.questions)

    def __getitem__(self, idx):
        question = self.questions[idx]
        image_path = os.path.join(self.image_dir, question['image_filename'])

        # Verificar si el archivo existe antes de cargarlo
        if not os.path.exists(image_path):
            print(f"Advertencia: Imagen {image_path} no encontrada, omitiendo.")
            return None

        image = Image.open(image_path).convert('RGB')
        question_text = question['question'][:self.max_length]
        question_tensor = torch.tensor([ord(c) for c in question_text], dtype=torch.long)
        if question_tensor.size(0) < self.max_length:
            question_tensor = torch.nn.functional.pad(question_tensor, (0, self.max_length - question_tensor.size(0)))
        label = int(question['answer']) if question['answer'].isdigit() else 0
        if self.transform:
            image = self.transform(image)
        return image, question_tensor, label

def collate_fn(batch):
    # Filtrar entradas None (imágenes faltantes)
    batch = [item for item in batch if item is not None]
    images, questions, labels = zip(*batch)
    images = torch.stack(images)
    questions = torch.stack(questions)
    labels = torch.tensor(labels)
    return images, questions, labels

# ------------------- Función de Evaluación -------------------

def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, questions, labels in tqdm(dataloader, desc="Evaluando"):
            images, questions, labels = images.to(device), questions.to(device), labels.to(device)
            outputs = model(images, questions)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = total_loss / len(dataloader)
    accuracy = accuracy_score(all_labels, all_preds) * 100  # Convertir a porcentaje
    print(f"Pérdida media: {avg_loss:.4f}, Precisión: {accuracy:.2f}%")
    return avg_loss, accuracy

# ------------------- Configuración y Carga del Modelo -------------------

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Calcular el max_length más grande entre los conjuntos de validación
max_length_original = calculate_max_length(os.path.join(clevr_original_dir, 'questions/CLEVR_val_questions.json'))
max_length_valA_10k = calculate_max_length(os.path.join(clevr_systematic_10k_dir, 'questions/CLEVR_valA_questions.json'))
max_length_valB_10k = calculate_max_length(os.path.join(clevr_systematic_10k_dir, 'questions/CLEVR_valB_questions.json'))

# Usar el mayor valor de max_length entre los conjuntos
max_length = max(max_length_original, max_length_valA_10k, max_length_valB_10k)
print(f"Max length usado en el modelo: {max_length}")

# Inicializar el modelo con el max_length calculado
model = FiLMNetwork(num_classes=28, max_length=max_length).to(device)

# Descargar y cargar los pesos del modelo finetuneado
checkpoint_path = "/home/gperaltag/mi_entorno/best_film_model_finetuning.pth"
# !wget -O {checkpoint_path} "https://www.dropbox.com/scl/fi/ups40j3l3nrjpcg5ias3d/best_film_model_finetuning.pth?rlkey=8rsffbjpi7wsh75rgu3qfx8k4&st=pxq24ntj&dl=1"
model.load_state_dict(torch.load(checkpoint_path, map_location=device))
print("Pesos del modelo cargados exitosamente.")

# ------------------- Preparación de los Datasets y Transformaciones -------------------

transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])

# Definir datasets con el max_length calculado y rutas ajustadas
val_data_original = CLEVRDataset(
    os.path.join(clevr_original_dir, 'images/val'),
    os.path.join(clevr_original_dir, 'questions/CLEVR_val_questions.json'),
    max_length=max_length,
    transform=transform
)

val_dataA_10k = CLEVRDataset(
    os.path.join(clevr_systematic_10k_dir, 'images/valA'),
    os.path.join(clevr_systematic_10k_dir, 'questions/CLEVR_valA_questions.json'),
    max_length=max_length,
    transform=transform
)

val_dataB_10k = CLEVRDataset(
    os.path.join(clevr_systematic_10k_dir, 'images/valB'),
    os.path.join(clevr_systematic_10k_dir, 'questions/CLEVR_valB_questions.json'),
    max_length=max_length,
    transform=transform
)

val_loader_original = DataLoader(val_data_original, batch_size=64, collate_fn=collate_fn, num_workers=32)
val_loaderA_10k = DataLoader(val_dataA_10k, batch_size=64, collate_fn=collate_fn, num_workers=32)
val_loaderB_10k = DataLoader(val_dataB_10k, batch_size=64, collate_fn=collate_fn, num_workers=32)

# ------------------- Evaluación -------------------

criterion = nn.CrossEntropyLoss()

print("Evaluación en el conjunto de validación original de CLEVR:")
evaluate(model, val_loader_original, criterion, device)

print("Evaluación en el conjunto de validación ValA (10k) de CLEVR fine-tuning:")
evaluate(model, val_loaderA_10k, criterion, device)

print("Evaluación en el conjunto de validación ValB (10k) de CLEVR fine-tuning:")
evaluate(model, val_loaderB_10k, criterion, device)
# Out:
# Max length usado en el modelo: 208
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:00<00:00, 227MB/s]
# --2024-11-11 18:39:22--  https://www.dropbox.com/scl/fi/ups40j3l3nrjpcg5ias3d/best_film_model_finetuning.pth?rlkey=8rsffbjpi7wsh75rgu3qfx8k4&st=pxq24ntj&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com/cd/0/inline/CeNlOa7ARKLFuQzV9R99CoVLyKo_jRwCxgeSIeZnbuT3xHnvm1L4zJVzbgHUVhQ69zq9iK3EXzbl_LxP1ofL2jvBoz6QJLSdWuCjgANrHejxO2AA6PKS_wJz3ONqeHGj3aqZqiPwT8gES4WBcFyj-R1B/file?dl=1# [following]
# --2024-11-11 18:39:23--  https://uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com/cd/0/inline/CeNlOa7ARKLFuQzV9R99CoVLyKo_jRwCxgeSIeZnbuT3xHnvm1L4zJVzbgHUVhQ69zq9iK3EXzbl_LxP1ofL2jvBoz6QJLSdWuCjgANrHejxO2AA6PKS_wJz3ONqeHGj3aqZqiPwT8gES4WBcFyj-R1B/file?dl=1
# Resolving uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com (uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com (uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CeOLTasbBDCOwOcZojmKcmiY_E-vdmAk0lxoT_4Vu45i5YZr1GU0hEMswID8qbCvEqsToqYf0WToNC4-fmo4BqV-9Zdxr9t4D68ov7jFygVLn6uVc2g9lmFd8DZN-UZdVj8x-KPrNBGXWOuAygIV7_fPuzqvKaf20pYybu4lO6CoD7wMDbgKHvAq_4Sy7Qupl0-s9DBoQujlh3de8ARAZxGT9mcY_L9SgKl7yVXVFX-MFm0ah7adzd7mXZSzc2AzBw_j42hvKlB0cU-cf3jSyCXLVhdPJoSYeQfRW-mxm-VCVj4nTyxgZJdpg6-UyTmVNbW-xyFQF6GdrJYAxnZyGu8EX13-w8AigOqU22z_71GwEt5UoHsDLbL0HbCdTmSAwWQ/file?dl=1 [following]
# --2024-11-11 18:39:24--  https://uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com/cd/0/inline2/CeOLTasbBDCOwOcZojmKcmiY_E-vdmAk0lxoT_4Vu45i5YZr1GU0hEMswID8qbCvEqsToqYf0WToNC4-fmo4BqV-9Zdxr9t4D68ov7jFygVLn6uVc2g9lmFd8DZN-UZdVj8x-KPrNBGXWOuAygIV7_fPuzqvKaf20pYybu4lO6CoD7wMDbgKHvAq_4Sy7Qupl0-s9DBoQujlh3de8ARAZxGT9mcY_L9SgKl7yVXVFX-MFm0ah7adzd7mXZSzc2AzBw_j42hvKlB0cU-cf3jSyCXLVhdPJoSYeQfRW-mxm-VCVj4nTyxgZJdpg6-UyTmVNbW-xyFQF6GdrJYAxnZyGu8EX13-w8AigOqU22z_71GwEt5UoHsDLbL0HbCdTmSAwWQ/file?dl=1
# Reusing existing connection to uc50d9c2fcb77b4a2912862197f7.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 331978915 (317M) [application/binary]
# Saving to: ‘/home/gperaltag/mi_entorno/best_film_model_finetuning.pth’
#
# /home/gperaltag/mi_ 100%[===================>] 316.60M  13.2MB/s    in 17s
#
# 2024-11-11 18:39:42 (18.2 MB/s) - ‘/home/gperaltag/mi_entorno/best_film_model_finetuning.pth’ saved [331978915/331978915]
# <ipython-input-2-8fbede144fd6>:179: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path, map_location=device))
# Pesos del modelo cargados exitosamente.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Evaluación en el conjunto de validación original de CLEVR:
# Evaluando: 100%|██████████| 2344/2344 [13:28<00:00,  2.90it/s]
# Pérdida media: 0.3187, Precisión: 85.65%
# Evaluación en el conjunto de validación ValA (10k) de CLEVR fine-tuning:
# Evaluando:   0%|          | 0/313 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Evaluando: 100%|██████████| 313/313 [01:51<00:00,  2.80it/s]
# Pérdida media: 0.2923, Precisión: 87.70%
# Evaluación en el conjunto de validación ValB (10k) de CLEVR fine-tuning:
# Evaluando:   0%|          | 0/313 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 32 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Evaluando: 100%|██████████| 313/313 [01:51<00:00,  2.81it/s]
# Pérdida media: 0.2937, Precisión: 87.69%
# (0.29367180309070945, 87.685)
